# %% [markdown]
# Text Visualizations with WordCloud on Datasets - Coding Assignment
#
# Assignment-20
# Write a Python script to generate a WordCloud from the text: 'data science machine learning artificial intelligence'. Save the WordCloud as an image.

# %%
pip install wordcloud matplotlib
# Out:
# Requirement already satisfied: wordcloud in c:\users\hp\anaconda3\anaconda4\lib\site-packages (1.9.4)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\anaconda4\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\hp\anaconda3\anaconda4\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\anaconda4\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\anaconda4\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\anaconda4\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\anaconda4\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\anaconda3\anaconda4\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\anaconda4\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\anaconda4\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\anaconda4\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\anaconda4\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_wordcloud(text):
    # Create a WordCloud object
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    
    # Save the WordCloud image as 'wordcloud.png'
    wordcloud.to_file('wordcloud.png')
    
    # Display the WordCloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')  # Hide the axis
    plt.show()

# Text to generate the WordCloud from
text = 'data science machine learning artificial intelligence'

# Generate and save the WordCloud
generate_wordcloud(text)
